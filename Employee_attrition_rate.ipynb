# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Id  Age  Attrition BusinessTravel              Department  \
# 0   1   30          0     Non-Travel  Research & Development
# 1   2   36          0  Travel_Rarely  Research & Development
# 2   3   55          1  Travel_Rarely                   Sales
# 3   4   39          0  Travel_Rarely  Research & Development
# 4   5   37          0  Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 2          3        Medical             571
# 1                12          4  Life Sciences            1614
# 2                 2          1        Medical             842
# 3                24          1  Life Sciences            2014
# 4                 3          3          Other             689
#
#    EnvironmentSatisfaction  ... PerformanceRating  StockOptionLevel  \
# 0                        3  ...                 3                 0
# 1                        3  ...                 3                 2
# ...

# %%
df.shape
# Out:
# (1628, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1628 entries, 0 to 1627
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Id                       1628 non-null   int64
#  1   Age                      1628 non-null   int64
#  2   Attrition                1628 non-null   int64
#  3   BusinessTravel           1628 non-null   object
#  4   Department               1628 non-null   object
#  5   DistanceFromHome         1628 non-null   int64
#  6   Education                1628 non-null   int64
#  7   EducationField           1628 non-null   object
#  8   EmployeeNumber           1628 non-null   int64
#  9   EnvironmentSatisfaction  1628 non-null   int64
#  10  Gender                   1628 non-null   object
#  11  JobInvolvement           1628 non-null   int64
#  12  JobRole                  1628 non-null   object
#  13  JobSatisfaction          1628 non-null   int64
# ...

# %%
plt.figure(figsize=(20,6))
sns.heatmap(df.isnull(), yticklabels= False, cbar = False)

# %%
df.describe()
# Out:
#                 Id          Age    Attrition  DistanceFromHome    Education  \
# count  1628.000000  1628.000000  1628.000000       1628.000000  1628.000000
# mean    814.500000    35.645577     0.482187          9.735258     2.884521
# std     470.107435     9.481794     0.499836          8.306546     1.020470
# min       1.000000    18.000000     0.000000          1.000000     1.000000
# 25%     407.750000    29.000000     0.000000          2.000000     2.000000
# 50%     814.500000    34.000000     0.000000          8.000000     3.000000
# 75%    1221.250000    42.000000     1.000000         15.000000     4.000000
# max    1628.000000    60.000000     1.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction  JobInvolvement  \
# count     1628.000000              1628.000000     1628.000000
# mean      1000.985872                 2.646192        2.650491
# std        585.417694                 1.125283        0.736330
# ...

# %%
#EDA of given dataset with respect to Attrition Rate..

# %%
#Histogram of all numerical data..

df.hist(figsize= (20,20))
plt.show()

# %%
                                        # AGE, GENDER, MARTITIAL STATUS, EDUCATION

# %%
#Age wise count of arrition rate..

plt.figure(figsize=(20,5))
sns.countplot(x = 'Age', data =df, hue ='Attrition')

df.groupby('Age')['Attrition'].value_counts()
# Out:
# Age  Attrition
# 18   1            10
#      0             3
# 19   1            20
#      0             3
# 20   1            25
#                   ..
# 57   0             3
# 58   1            10
#      0             5
# 59   0             8
# 60   0             3
# Name: Attrition, Length: 82, dtype: int64

# %%
#Age distribution in percent by attrition status

plt.figure(figsize=(12,5))
sns.kdeplot(df[df['Attrition'] == 0]['Age'], label = 'Active employee')
sns.kdeplot(df[df['Attrition'] == 1]['Age'], label = 'Left employee')
plt.grid(True, alpha=0.5)
plt.xlabel('Age (years)')
plt.ylabel('Density')
plt.title('Age Distribution in Percent by Attrition Status')
# Out:
# Text(0.5, 1.0, 'Age Distribution in Percent by Attrition Status')

# %%
#Gender wise count of attriton rate..

plt.figure(figsize=(6,5))
sns.countplot(x = 'Attrition', data= df, hue = 'Gender')

df.groupby('Gender')['Attrition'].value_counts()
# Out:
# Gender  Attrition
# Female  0            337
#         1            295
# Male    0            506
#         1            490
# Name: Attrition, dtype: int64

# %%
#Maritial status wise count of attrition rate..

sns.countplot(x = 'MaritalStatus', data =df, hue= 'Attrition')
df.groupby('MaritalStatus')['Attrition'].value_counts()
# Out:
# MaritalStatus  Attrition
# Divorced       0            192
#                1            125
# Married        0            416
#                1            265
# Single         1            395
#                0            235
# Name: Attrition, dtype: int64

# %%
#Education field wise count of attrtion rate..

plt.figure(figsize=(12,5))
sns.countplot(x = 'EducationField', hue = 'Attrition', data = df)
df.groupby('EducationField')['Attrition'].value_counts()
# Out:
# EducationField    Attrition
# Human Resources   1             25
#                   0             15
# Life Sciences     0            348
#                   1            275
# Marketing         1            115
#                   0             82
# Medical           0            286
#                   1            235
# Other             0             50
#                   1             35
# Technical Degree  1            100
#                   0             62
# Name: Attrition, dtype: int64

# %%
                                            # EDUCATION, EDUCATION FILED

# %%
#Education wise count of attrtion rate.

plt.figure(figsize=(8,5))
sns.countplot(x = 'Education', hue = 'Attrition', data = df)
df.groupby('Education')['Attrition'].value_counts()
# Out:
# Education  Attrition
# 1          0            101
#            1            100
# 2          1            155
#            0            151
# 3          0            329
#            1            315
# 4          0            234
#            1            200
# 5          0             28
#            1             15
# Name: Attrition, dtype: int64

# %%
#Education distribution in percent by attrition status

plt.figure(figsize=(15,5))
sns.kdeplot(df[df['Attrition'] == 0]['Education'], label = 'Active employee')
sns.kdeplot(df[df['Attrition'] == 1]['Education'], label = 'Left employee')
plt.grid(True, alpha=0.5)
plt.xlabel('Education (level)')
plt.ylabel('Density')
plt.title('Education Distribution in Percent by Attrition Status')
# Out:
# Text(0.5, 1.0, 'Education Distribution in Percent by Attrition Status')

# %%
#Travel distance from home wise count of attrtion rate..

plt.figure(figsize=(15,5))
sns.countplot(x = 'DistanceFromHome', hue = 'Attrition', data = df)
df.groupby('DistanceFromHome')['Attrition'].value_counts()
# Out:
# DistanceFromHome  Attrition
# 1                 0            124
#                   1             90
# 2                 0            126
#                   1             85
# 3                 0             44
#                   1             40
# 4                 1             40
#                   0             37
# 5                 1             40
#                   0             36
# 6                 0             41
#                   1             15
# 7                 0             57
#                   1             25
# 8                 0             46
#                   1             30
# 9                 1             80
#                   0             49
# 10                0             50
#                   1             40
# 11                0             18
#                   1             15
# 12                1             20
#                   0             10
# 13                1             15
#                   0              9
# ...

# %%
                                    # BUSINESS TRAVEL, TRAVEL DISTANCE FROM HOME

# %%
#Distance from home distribution in percent by attrition status

plt.figure(figsize=(15,5))
sns.kdeplot(df[df['Attrition'] == 0]['DistanceFromHome'], label = 'Active employee')
sns.kdeplot(df[df['Attrition'] == 1]['DistanceFromHome'], label = 'Left employee')
plt.grid(True, alpha=0.5)
plt.xlabel('Distance from home (km)')
plt.ylabel('Density')
plt.title('Distance from home Distribution in Percent by Attrition Status')
# Out:
# Text(0.5, 1.0, 'Distance from home Distribution in Percent by Attrition Status')

# %%
# Business travel wise count of attrition rate..

plt.figure(figsize=(10,5))
sns.countplot(x ='BusinessTravel', data =df, hue = 'Attrition')
df.groupby('BusinessTravel')['Attrition'].value_counts()
# Out:
# BusinessTravel     Attrition
# Non-Travel         0             85
#                    1             35
# Travel_Frequently  1            255
#                    0            148
# Travel_Rarely      0            610
#                    1            495
# Name: Attrition, dtype: int64

# %%
                     # DEPARTMENT, JOB ROLE, JOB INVOLVEMENT, JOB SATISFACTION, ENVIROMENTAL SATISFACTION

# %%
#Department wise count of attriton rate..

plt.figure(figsize=(10,5))
sns.countplot(x = 'Department', data =df, hue = 'Attrition')
df.groupby('Department')['Attrition'].value_counts()
# Out:
# Department              Attrition
# Human Resources         1             45
#                         0             36
# Research & Development  0            564
#                         1            415
# Sales                   1            325
#                         0            243
# Name: Attrition, dtype: int64

# %%
#Job Role  wise count of attriton rate..

plt.figure(figsize=(20,5))
sns.set_context('paper', font_scale = 1.1)
sns.countplot(x = 'JobRole',data =df, hue = 'Attrition')
df.groupby('JobRole')['Attrition'].value_counts()
# Out:
# JobRole                    Attrition
# Healthcare Representative  0             85
#                            1             25
# Human Resources            1             45
#                            0             27
# Laboratory Technician      1            180
#                            0            130
# Manager                    0             70
#                            1             20
# Manufacturing Director     0             91
#                            1             30
# Research Director          0             47
# Research Scientist         0            176
#                            1            165
# Sales Executive            1            185
#                            0            180
# Sales Representative       1            135
#                            0             37
# Name: Attrition, dtype: int64

# %%
#Job Involvement wise count of attriton rate..

plt.figure(figsize=(10,5))
sns.countplot(x = 'JobInvolvement',data =df, hue = 'Attrition')
df.groupby('JobInvolvement')['Attrition'].value_counts()
# Out:
# JobInvolvement  Attrition
# 1               1             90
#                 0             36
# 2               1            235
#                 0            212
# 3               0            510
#                 1            415
# 4               0             85
#                 1             45
# Name: Attrition, dtype: int64

# %%
#Job Satisfaction wise count of attriton rate..

plt.figure(figsize=(10,5))
sns.countplot(x = 'JobSatisfaction',data =df, hue = 'Attrition')
df.groupby('JobSatisfaction')['Attrition'].value_counts()
# Out:
# JobSatisfaction  Attrition
# 1                1            210
#                  0            146
# 2                1            155
#                  0            154
# 3                0            269
#                  1            260
# 4                0            274
#                  1            160
# Name: Attrition, dtype: int64

# %%
#Job Involvement distribution in percent by attrition status

plt.figure(figsize=(10,5))
sns.kdeplot(df[df['Attrition'] == 0]['JobInvolvement'], label = 'Active employee')
sns.kdeplot(df[df['Attrition'] == 1]['JobInvolvement'], label = 'Left employee')
plt.grid(True, alpha=0.5)
plt.xlabel('Job Involvement (level)')
plt.ylabel('Density')
plt.title('Job Involvement Distribution in Percent by Attrition Status')
# Out:
# Text(0.5, 1.0, 'Job Involvement Distribution in Percent by Attrition Status')

# %%
#Environment Satisfaction wise count of attriton rate..

plt.figure(figsize=(10,5))
sns.countplot(x = 'EnvironmentSatisfaction',data =df, hue = 'Attrition')
df.groupby('EnvironmentSatisfaction')['Attrition'].value_counts()
# Out:
# EnvironmentSatisfaction  Attrition
# 1                        1            225
#                          0            147
# 2                        0            169
#                          1            135
# 3                        0            260
#                          1            220
# 4                        0            267
#                          1            205
# Name: Attrition, dtype: int64

# %%
#Environment Satisfaction distribution in percent by attrition status

plt.figure(figsize=(15,5))
sns.kdeplot(df[df['Attrition'] == 0]['EnvironmentSatisfaction'], label = 'Active employee')
sns.kdeplot(df[df['Attrition'] == 1]['EnvironmentSatisfaction'], label = 'Left employee')
plt.grid(True, alpha=0.5)
plt.xlabel('Environment Satisfaction (level)')
plt.ylabel('Density')
plt.title('Environment Satisfaction Distribution in Percent by Attrition Status')
# Out:
# Text(0.5, 1.0, 'Environment Satisfaction Distribution in Percent by Attrition Status')

# %%
                               #OverTime, Performance Rating, Communication Skill

# %%
#Job Satisfaction wise count of attriton rate..

sns.countplot(x = 'OverTime',data =df, hue = 'Attrition')
df.groupby('OverTime')['Attrition'].value_counts()
# Out:
# OverTime  Attrition
# No        0            645
#           1            355
# Yes       1            430
#           0            198
# Name: Attrition, dtype: int64

# %%
#Performance Rating wise count of attriton rate..

sns.countplot(x = 'PerformanceRating',data =df, hue = 'Attrition')
df.groupby('PerformanceRating')['Attrition'].value_counts()
# Out:
# PerformanceRating  Attrition
# 3                  0            715
#                    1            660
# 4                  0            128
#                    1            125
# Name: Attrition, dtype: int64

# %%
#Communication Skill wise count of attriton rate..

plt.figure(figsize=(10,5))
sns.countplot(x = 'CommunicationSkill',data =df, hue = 'Attrition')
df.groupby('CommunicationSkill')['Attrition'].value_counts()
# Out:
# CommunicationSkill  Attrition
# 1                   0            173
#                     1            100
# 2                   1            165
#                     0            160
# 3                   0            173
#                     1            140
# 4                   0            172
#                     1            170
# 5                   1            210
#                     0            165
# Name: Attrition, dtype: int64

# %%
                                      # MONTHLY INCOME, PERCENT SALARY HIKE

# %%
#Monthly Income distribution in percent by attrition status

plt.figure(figsize=(15,5))
sns.kdeplot(df[df['Attrition'] == 0]['MonthlyIncome'], label = 'Active employee')
sns.kdeplot(df[df['Attrition'] == 1]['MonthlyIncome'], label = 'Left employee')
plt.grid(True, alpha=0.5)
plt.xlabel('Monthly Income (INR)')
plt.ylabel('Density')
plt.title('Monthly Income in Percent by Attrition Status')
# Out:
# Text(0.5, 1.0, 'Monthly Income in Percent by Attrition Status')

# %%
#Percent Salary Hike distribution in percent by attrition status

plt.figure(figsize=(15,5))
sns.kdeplot(df[df['Attrition'] == 0]['PercentSalaryHike'], label = 'Active employee')
sns.kdeplot(df[df['Attrition'] == 1]['PercentSalaryHike'], label = 'Left employee')
plt.grid(True, alpha=0.5)
plt.xlabel('Percent Salary Hike (%)')
plt.ylabel('Density')
plt.title('Percent Salary Hike in Percent by Attrition Status')
# Out:
# Text(0.5, 1.0, 'Percent Salary Hike in Percent by Attrition Status')

# %%
                                    #NUMBER OF COMPANIES WORKED , TOTAL WORKING YEARS

# %%
#Num Companies Worked distribution in percent by attrition status

plt.figure(figsize=(15,5))
sns.kdeplot(df[df['Attrition'] == 0]['NumCompaniesWorked'], label = 'Active employee')
sns.kdeplot(df[df['Attrition'] == 1]['NumCompaniesWorked'], label = 'Left employee')
plt.grid(True, alpha=0.5)
plt.xlabel('Num Companies Worked (Nos.)')
plt.ylabel('Density')
plt.title('Num Companies Worked in Percent by Attrition Status')
# Out:
# Text(0.5, 1.0, 'Num Companies Worked in Percent by Attrition Status')

# %%
#Total Working Years distribution in percent by attrition status

plt.figure(figsize=(15,5))
sns.kdeplot(df[df['Attrition'] == 0]['TotalWorkingYears'], label = 'Active employee')
sns.kdeplot(df[df['Attrition'] == 1]['TotalWorkingYears'], label = 'Left employee')
plt.grid(True, alpha=0.5)
plt.xlabel('Total Working Years (Yrs.)')
plt.ylabel('Density')
plt.title('Total Working Years in Percent by Attrition Status')
# Out:
# Text(0.5, 1.0, 'Total Working Years in Percent by Attrition Status')

# %%
         # TrainingTimesLastYear, YearsAtCompany, YearsInCurrentRole,YearsSinceLastPromotion, YearsWithCurrManager

# %%
#Training Times Last Year distribution in percent by attrition status

plt.figure(figsize=(15,5))
sns.kdeplot(df[df['Attrition'] == 0]['TrainingTimesLastYear'], label = 'Active employee')
sns.kdeplot(df[df['Attrition'] == 1]['TrainingTimesLastYear'], label = 'Left employee')
plt.grid(True, alpha=0.5)
plt.xlabel('Training Times Las tYear (Yrs.)')
plt.ylabel('Density')
plt.title('Training Times Last Year in Percent by Attrition Status')
# Out:
# Text(0.5, 1.0, 'Training Times Last Year in Percent by Attrition Status')

# %%
#Years At Company Hike distribution in percent by attrition status

plt.figure(figsize=(15,5))
sns.kdeplot(df[df['Attrition'] == 0]['YearsAtCompany'], label = 'Active employee')
sns.kdeplot(df[df['Attrition'] == 1]['YearsAtCompany'], label = 'Left employee')
plt.grid(True, alpha=0.5)
plt.xlabel('Years At Company (Yrs.)')
plt.ylabel('Density')
plt.title('Years At Company in Percent by Attrition Status')
# Out:
# Text(0.5, 1.0, 'Years At Company in Percent by Attrition Status')

# %%
#Years In Current Role distribution in percent by attrition status

plt.figure(figsize=(15,5))
sns.kdeplot(df[df['Attrition'] == 0]['YearsInCurrentRole'], label = 'Active employee')
sns.kdeplot(df[df['Attrition'] == 1]['YearsInCurrentRole'], label = 'Left employee')
plt.grid(True, alpha=0.5)
plt.xlabel('Years In Current Role (Yrs.)')
plt.ylabel('Density')
plt.title('Years In Current Role in Percent by Attrition Status')
# Out:
# Text(0.5, 1.0, 'Years In Current Role in Percent by Attrition Status')

# %%
#Years Since Last Promotion distribution in percent by attrition status

plt.figure(figsize=(15,5))
sns.kdeplot(df[df['Attrition'] == 0]['YearsSinceLastPromotion'], label = 'Active employee')
sns.kdeplot(df[df['Attrition'] == 1]['YearsSinceLastPromotion'], label = 'Left employee')
plt.grid(True, alpha=0.5)
plt.xlabel('Years Since Last Promotion (Yrs.)')
plt.ylabel('Density')
plt.title('Years Since Last Promotion in Percent by Attrition Status')
# Out:
# Text(0.5, 1.0, 'Years Since Last Promotion in Percent by Attrition Status')

# %%
#Years With Curr Manager Hike distribution in percent by attrition status

plt.figure(figsize=(15,5))
sns.kdeplot(df[df['Attrition'] == 0]['YearsWithCurrManager'], label = 'Active employee')
sns.kdeplot(df[df['Attrition'] == 1]['YearsWithCurrManager'], label = 'Left employee')
plt.grid(True, alpha=0.5)
plt.xlabel('Years With Curr Manager (Yrs.)')
plt.ylabel('Density')
plt.title('Years With Curr Manager in Percent by Attrition Status')
# Out:
# Text(0.5, 1.0, 'Years With Curr Manager in Percent by Attrition Status')

# %%
plt.figure(figsize =(18,18))
sns.heatmap(df.corr(),annot = True)

# %%
#Now preprocssing the data

# %%
df = df.drop(['Behaviour','EmployeeNumber'], axis =1)

# %%
df.shape
# Out:
# (1628, 27)

# %%
from sklearn.preprocessing import LabelEncoder

for i in df.columns:
    if df[i].dtype == np.number: 
        continue 
    else:
        df[i] = LabelEncoder().fit_transform(df[i])

# %%
df.head()
# Out:
#    Id  Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0   0   12          0               0           1                 1
# 1   1   18          0               2           1                11
# 2   2   37          1               2           2                 1
# 3   3   21          0               2           1                23
# 4   4   19          0               2           1                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0          2               3                        2       0  ...
# 1          3               1                        2       0  ...
# 2          0               3                        2       1  ...
# 3          0               1                        0       1  ...
# 4          2               4                        2       1  ...
#
#    PercentSalaryHike  PerformanceRating  StockOptionLevel  TotalWorkingYears  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 5))
df_col = list(df.columns)
df_col.remove('Attrition')
for col in df_col:
    df[col] = df[col].astype(float)
    df[[col]] = scaler.fit_transform(df[[col]])
df['Attrition'] = pd.to_numeric(df['Attrition'], downcast='float')
df.head()
# Out:
#          Id       Age  Attrition  BusinessTravel  Department  \
# 0  0.000000  1.428571        0.0             0.0         2.5
# 1  0.003073  2.142857        0.0             5.0         2.5
# 2  0.006146  4.404762        1.0             5.0         5.0
# 3  0.009219  2.500000        0.0             5.0         2.5
# 4  0.012293  2.261905        0.0             5.0         2.5
#
#    DistanceFromHome  Education  EducationField  EnvironmentSatisfaction  \
# 0          0.178571       2.50             3.0                 3.333333
# 1          1.964286       3.75             1.0                 3.333333
# 2          0.178571       0.00             3.0                 3.333333
# 3          4.107143       0.00             1.0                 0.000000
# 4          0.357143       2.50             4.0                 3.333333
#
#    Gender  ...  PercentSalaryHike  PerformanceRating  StockOptionLevel  \
# 0     0.0  ...           1.071429                0.0          0.000000
# ...

# %%
df.head()
# Out:
#          Id       Age  Attrition  BusinessTravel  Department  \
# 0  0.000000  1.428571        0.0             0.0         2.5
# 1  0.003073  2.142857        0.0             5.0         2.5
# 2  0.006146  4.404762        1.0             5.0         5.0
# 3  0.009219  2.500000        0.0             5.0         2.5
# 4  0.012293  2.261905        0.0             5.0         2.5
#
#    DistanceFromHome  Education  EducationField  EnvironmentSatisfaction  \
# 0          0.178571       2.50             3.0                 3.333333
# 1          1.964286       3.75             1.0                 3.333333
# 2          0.178571       0.00             3.0                 3.333333
# 3          4.107143       0.00             1.0                 0.000000
# 4          0.357143       2.50             4.0                 3.333333
#
#    Gender  ...  PercentSalaryHike  PerformanceRating  StockOptionLevel  \
# 0     0.0  ...           1.071429                0.0          0.000000
# ...

# %%
X = df.drop('Attrition', axis =1).values
y = df['Attrition'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(n_estimators= 10, criterion='entropy',random_state= 0)
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
clf.score(X_train,y_train)
# Out:
# 0.9893529893529893

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
cm = confusion_matrix(y_test,clf.predict(X_test))

# %%
print(classification_report(y_test,clf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.97      0.90       200
#          1.0       0.97      0.81      0.88       207
#
#     accuracy                           0.89       407
#    macro avg       0.90      0.89      0.89       407
# weighted avg       0.90      0.89      0.89       407

# %%
cm
# Out:
# array([[195,   5],
#        [ 39, 168]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,clf.predict(X_test)))
# Out:
# 0.8918918918918919

# %%
data = pd.read_csv('test.csv')
data.head()
# Out:
#    Id  Age BusinessTravel              Department  DistanceFromHome  \
# 0   1   28  Travel_Rarely  Research & Development                 9
# 1   2   31  Travel_Rarely                   Sales                 6
# 2   3   37  Travel_Rarely  Research & Development                 6
# 3   4   42  Travel_Rarely  Research & Development                 1
# 4   5   45     Non-Travel  Research & Development                 4
#
#    Education EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0          3        Medical             377                        4    Male
# 1          4        Medical             653                        1    Male
# 2          3        Medical             474                        3    Male
# 3          2  Life Sciences             827                        4  Female
# 4          2  Life Sciences             972                        3    Male
#
#    ...  PerformanceRating StockOptionLevel  TotalWorkingYears  \
# ...

# %%
data = data.drop(['Behaviour','EmployeeNumber'], axis =1)

# %%
for i in data.columns:
    if data[i].dtype == np.number: 
        continue 
    else:
        data[i] = LabelEncoder().fit_transform(data[i])

# %%
classifier = clf.fit(X_train,y_train)
pred = classifier.predict_proba(data)

# %%
print(pred)
# Out:
# [[1.  0. ]
#  [1.  0. ]
#  [0.9 0.1]
#  [1.  0. ]
#  [0.1 0.9]
#  [0.1 0.9]
#  [0.1 0.9]
#  [0.  1. ]
#  [0.1 0.9]
#  [0.1 0.9]
#  [0.1 0.9]
#  [0.2 0.8]
#  [0.  1. ]
#  [0.1 0.9]
#  [0.  1. ]
#  [0.  1. ]
#  [0.  1. ]
#  [0.1 0.9]
#  [0.  1. ]
#  [0.3 0.7]
#  [0.1 0.9]
#  [0.1 0.9]
#  [0.  1. ]
#  [0.1 0.9]
#  [0.  1. ]
#  [0.3 0.7]
#  [0.1 0.9]
#  [0.2 0.8]
#  [0.1 0.9]
#  [0.2 0.8]
#  [0.2 0.8]
#  [0.1 0.9]
#  [0.  1. ]
#  [0.2 0.8]
#  [0.1 0.9]
#  [0.  1. ]
#  [0.1 0.9]
#  [0.2 0.8]
#  [0.  1. ]
#  [0.  1. ]
#  [0.  1. ]
#  [0.1 0.9]
#  [0.  1. ]
#  [0.1 0.9]
#  [0.2 0.8]
#  [0.  1. ]
#  [0.  1. ]
#  [0.2 0.8]
#  [0.2 0.8]
#  [0.  1. ]
#  [0.  1. ]
#  [0.1 0.9]
#  [0.1 0.9]
#  [0.1 0.9]
#  [0.  1. ]
#  [0.1 0.9]
#  [0.2 0.8]
#  [0.1 0.9]
#  [0.2 0.8]
#  [0.2 0.8]
#  [0.2 0.8]
#  [0.  1. ]
#  [0.  1. ]
#  [0.3 0.7]
#  [0.  1. ]
#  [0.  1. ]
#  [0.1 0.9]
#  [0.1 0.9]
#  [0.1 0.9]
#  [0.1 0.9]
#  [0.1 0.9]
#  [0.  1. ]
#  [0.1 0.9]
#  [0.  1. ]
#  [0.  1. ]
#  [0.  1. ]
# ...

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

#ROC for Random Forrest
clf_roc_auc = roc_auc_score(y_test, clf.predict(X_test))
clf_fpr, clf_tpr, clf_thresholds = roc_curve(y_test, clf.predict_proba(X_test)[:,1])

#ROC Curve for Random Forest & Logistic Regression
plt.figure()
plt.plot(clf_fpr, clf_tpr, label='Random Forest (area = %0.2f)' % clf_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('ROC')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.91      0.86       200
#          1.0       0.90      0.80      0.85       207
#
#     accuracy                           0.85       407
#    macro avg       0.86      0.85      0.85       407
# weighted avg       0.86      0.85      0.85       407

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[182  18]
#  [ 42 165]]

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_test, predictions))
# Out:
# 0.8525798525798526

# %%
logger = logmodel.fit(X_train,y_train)
pred1 = logger.predict_proba(data)

# %%
print(pred1)
# Out:
# [[9.99999979e-01 2.07126023e-08]
#  [1.00000000e+00 1.28616014e-55]
#  [1.00000000e+00 1.38658112e-59]
#  [1.00000000e+00 8.69361960e-60]
#  [1.00000000e+00 4.12084677e-42]
#  [1.00000000e+00 1.77933954e-75]
#  [9.99999962e-01 3.78494799e-08]
#  [1.00000000e+00 4.76617577e-56]
#  [9.99995046e-01 4.95392076e-06]
#  [1.00000000e+00 2.54622758e-24]
#  [1.00000000e+00 2.65002643e-84]
#  [1.00000000e+00 1.92676990e-29]
#  [1.00000000e+00 1.83690115e-57]
#  [1.00000000e+00 4.65545973e-21]
#  [1.00000000e+00 1.98642234e-59]
#  [1.00000000e+00 6.39848856e-34]
#  [1.00000000e+00 5.90203724e-53]
#  [1.00000000e+00 2.40707492e-52]
#  [1.00000000e+00 9.67742635e-60]
#  [1.00000000e+00 4.96783034e-53]
#  [1.00000000e+00 2.15050527e-54]
#  [4.48559648e-01 5.51440352e-01]
#  [9.99949965e-01 5.00349668e-05]
#  [1.00000000e+00 7.63066445e-53]
#  [1.00000000e+00 5.34085095e-16]
#  [1.00000000e+00 6.26529370e-67]
#  [1.00000000e+00 2.49606544e-32]
#  [1.00000000e+00 3.56425318e-54]
# ...

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

#ROC for logistic regression
logmodel_roc_auc = roc_auc_score(y_test, logmodel.predict(X_test))
logmodel_fpr, logmodel_tpr, logmodel_thresholds = roc_curve(y_test, logmodel.predict_proba(X_test)[:,1])

#ROC Curve for Random Forest & Logistic Regression
plt.figure()
plt.plot(logmodel_fpr, logmodel_tpr, label='logistic regression (area = %0.2f)' % logmodel_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('ROC')
plt.show()

# %%
df.head()
# Out:
#          Id       Age  Attrition  BusinessTravel  Department  \
# 0  0.000000  1.428571        0.0             0.0         2.5
# 1  0.003073  2.142857        0.0             5.0         2.5
# 2  0.006146  4.404762        1.0             5.0         5.0
# 3  0.009219  2.500000        0.0             5.0         2.5
# 4  0.012293  2.261905        0.0             5.0         2.5
#
#    DistanceFromHome  Education  EducationField  EnvironmentSatisfaction  \
# 0          0.178571       2.50             3.0                 3.333333
# 1          1.964286       3.75             1.0                 3.333333
# 2          0.178571       0.00             3.0                 3.333333
# 3          4.107143       0.00             1.0                 0.000000
# 4          0.357143       2.50             4.0                 3.333333
#
#    Gender  ...  PercentSalaryHike  PerformanceRating  StockOptionLevel  \
# 0     0.0  ...           1.071429                0.0          0.000000
# ...
